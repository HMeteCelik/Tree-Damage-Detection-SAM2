# %%
import numpy as np
import torch
import cv2
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
import matplotlib.pyplot as plt
import pandas as pd
import xml.etree.ElementTree as ET
from PIL import Image, ImageDraw
import numpy as np
from PIL import Image
from bs4 import BeautifulSoup
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
import torch
import pandas as pd
import cv2
import matplotlib.pyplot as plt

test = pd.read_csv("test_data.csv")

sam2_checkpoint = "checkpoints/sam2_hiera_small.pt"
model_path = "model.torch"
num_samples = 30  

def read_image(image_path): 
    img = cv2.imread(image_path)[..., ::-1]  
    mask = np.ones(img.shape)

    r = np.min([1024 / img.shape[1], 1024 / img.shape[0]])
    img = cv2.resize(img, (int(img.shape[1] * r), int(img.shape[0] * r)))
    mask = cv2.resize(mask, (int(mask.shape[1] * r), int(mask.shape[0] * r)), interpolation=cv2.INTER_NEAREST)
    
    return img, mask

# %%
def get_points(mask, num_points): 
    points = []
    coords = np.argwhere(mask > 0)
    for i in range(num_points):
        yx = np.array(coords[np.random.randint(len(coords))])
        points.append([[yx[1], yx[0]]])
    return np.array(points)

# %%
model_cfg = "sam2_hiera_s.yaml"
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")
predictor = SAM2ImagePredictor(sam2_model)

# %%
import os
import numpy as np
import torch

output_dir = "output_images"
os.makedirs(output_dir, exist_ok=True)

predictor.model.load_state_dict(torch.load(model_path))
iou_values_0 = []  
iou_values_1 = []  

for j in range(len(test)):
    image_path = test.iloc[j]["image"]
    annotation_path = test.iloc[j]["annotation"]
    ann_map = cv2.imread(test.iloc[j]["Mask"])[...,::-1]

    ann_map = cv2.resize(ann_map, (1024,1024),interpolation=cv2.INTER_NEAREST)
    red_channel = ann_map[..., 0]

    _, gt_mask = cv2.threshold(red_channel, 1, 255, cv2.THRESH_BINARY)

    image, mask = read_image(image_path)
    input_points = get_points(mask, num_samples)

    with torch.inference_mode():
        predictor.set_image(image)
        masks, scores, logits = predictor.predict(
            point_coords=input_points,
            point_labels=np.ones([input_points.shape[0], 1])
        )

    masks = masks[:, 0].astype(bool)
    sorted_masks = masks[np.argsort(scores[:, 0])][::-1].astype(bool)

    seg_map = np.zeros_like(sorted_masks[0], dtype=np.uint8)
    occupancy_mask = np.zeros_like(sorted_masks[0], dtype=bool)

    for i in range(sorted_masks.shape[0]):
        mask = sorted_masks[i]
        
        if mask.sum() == 0:
            continue
        
        if (mask * occupancy_mask).sum() / mask.sum() > 0.15:
            continue
        
        mask[occupancy_mask] = 0
        seg_map[mask] = i + 1
        occupancy_mask[mask] = 1

    rgb_image = np.zeros((seg_map.shape[0], seg_map.shape[1], 3), dtype=np.uint8)
    for id_class in range(1, seg_map.max() + 1):
        rgb_image[seg_map == id_class] = [255, 0, 0]
    
    mix_image = ((rgb_image / 2 + image / 2).astype(np.uint8))

    mix_image_name = os.path.join(output_dir, f"tahmin{j}.png")
    
    prd_mask_0 = (sorted_masks[0] == 0).astype(np.float32)  
    gt_mask_0 = (gt_mask == 0).astype(np.float32)  
    
    intersection_0 = np.logical_and(gt_mask_0, prd_mask_0).sum()
    union_0 = np.logical_or(gt_mask_0, prd_mask_0).sum()
    
    if union_0 == 0:
        iou_0 = 0.0
    else:
        iou_0 = intersection_0 / union_0
    
    if iou_0 > 0.0:  
        iou_values_0.append(iou_0)  
    
    prd_mask_1 = (sorted_masks[0] == 1).astype(np.float32)  
    gt_mask_1 = (gt_mask == 255).astype(np.float32)  
    
    intersection_1 = np.logical_and(gt_mask_1, prd_mask_1).sum()
    union_1 = np.logical_or(gt_mask_1, prd_mask_1).sum()
    
    if union_1 == 0:
        iou_1 = 0.0
    else:
        iou_1 = intersection_1 / union_1
    
    if iou_1 > 0.0:  
        iou_values_1.append(iou_1)  
    
    
    print(f"Image {j}: IoU for label 0 = {iou_0}, IoU for label 1 = {iou_1}")

    
average_iou_0 = sum(iou_values_0) / len(iou_values_0)
average_iou_1 = sum(iou_values_1) / len(iou_values_1)
print(len(iou_values_0))
print(len(iou_values_1))
print(f"Average IoU for label 0: {average_iou_0}")
print(f"Average IoU for label 1: {average_iou_1}")
# Out:
# Image 0: IoU for label 0 = 0.923789254593611, IoU for label 1 = 0.6536823790096713
# Image 1: IoU for label 0 = 0.9861287591024298, IoU for label 1 = 0.4223764441591784
# Image 2: IoU for label 0 = 0.7927691279744477, IoU for label 1 = 0.7443131440041352
# Image 3: IoU for label 0 = 0.9377068672597519, IoU for label 1 = 0.7459525113062841
# Image 4: IoU for label 0 = 0.8796496392480974, IoU for label 1 = 0.7689360720055389
# Image 5: IoU for label 0 = 0.9400577545166016, IoU for label 1 = 0.0
# Image 6: IoU for label 0 = 0.9897775650024414, IoU for label 1 = 0.0
# Image 7: IoU for label 0 = 0.915069580078125, IoU for label 1 = 0.0
# Image 8: IoU for label 0 = 0.8606137868071398, IoU for label 1 = 0.3932338110283267
# Image 9: IoU for label 0 = 0.8600557335405964, IoU for label 1 = 0.6991310821532208
# Image 10: IoU for label 0 = 0.8653212871488845, IoU for label 1 = 0.6863589702300679
# Image 11: IoU for label 0 = 0.7111719307538938, IoU for label 1 = 0.6527456391748929
# Image 12: IoU for label 0 = 0.8709644104113421, IoU for label 1 = 0.7025343143582462
# Image 13: IoU for label 0 = 0.9308232855274089, IoU for label 1 = 0.7348605629753535
# Image 14: IoU for label 0 = 0.8318337262623384, IoU for label 1 = 0.680571924894874
# Image 15: IoU for label 0 = 0.8373583309551959, IoU for label 1 = 0.6737573790600803
# Image 16: IoU for label 0 = 0.859544203080605, IoU for label 1 = 0.7181796449507338
# Image 17: IoU for label 0 = 0.7648542459775551, IoU for label 1 = 0.7184168886647592
# Image 18: IoU for label 0 = 0.8062503305562774, IoU for label 1 = 0.5148513141188968
# Image 19: IoU for label 0 = 0.8410030465713529, IoU for label 1 = 0.5843196710309567
# Image 20: IoU for label 0 = 0.8388662645118599, IoU for label 1 = 0.6167230366671618
# Image 21: IoU for label 0 = 0.962065681292827, IoU for label 1 = 0.6774272630961449
# Image 22: IoU for label 0 = 0.9107017590957424, IoU for label 1 = 0.7148862429425904
# Image 23: IoU for label 0 = 0.8395767651734529, IoU for label 1 = 0.7153551916460691
# Image 24: IoU for label 0 = 0.8062408833753664, IoU for label 1 = 0.6890965486768251
# Image 25: IoU for label 0 = 0.8079891405333564, IoU for label 1 = 0.7173558999285921
# Image 26: IoU for label 0 = 0.8150337213049186, IoU for label 1 = 0.629833990746038
# Image 27: IoU for label 0 = 0.8033094427186647, IoU for label 1 = 0.7635594030544626
# Image 28: IoU for label 0 = 0.7972713661584284, IoU for label 1 = 0.6632277571866854
# Image 29: IoU for label 0 = 0.8580445371555144, IoU for label 1 = 0.7425155539952801
# Image 30: IoU for label 0 = 0.9474467256960913, IoU for label 1 = 0.6865815527268807
# Image 31: IoU for label 0 = 0.8909871289400672, IoU for label 1 = 0.46223585162926867
# Image 32: IoU for label 0 = 0.9484026500732672, IoU for label 1 = 0.630888128345422
# Image 33: IoU for label 0 = 0.9203213907539068, IoU for label 1 = 0.7342438320118295
# Image 34: IoU for label 0 = 0.8703897981989088, IoU for label 1 = 0.7449303259390345
# Image 35: IoU for label 0 = 0.8840994540985686, IoU for label 1 = 0.6873091202582728
# Image 36: IoU for label 0 = 0.7273969674296447, IoU for label 1 = 0.688008444437454
# Image 37: IoU for label 0 = 0.8257219397694808, IoU for label 1 = 0.7036049380451431
# Image 38: IoU for label 0 = 0.8067247090551989, IoU for label 1 = 0.7353085230238067
# Image 39: IoU for label 0 = 0.8514714207994537, IoU for label 1 = 0.6595418858852773
# Image 40: IoU for label 0 = 0.8628093369298032, IoU for label 1 = 0.7176941421852129
# Image 41: IoU for label 0 = 0.7831336835182765, IoU for label 1 = 0.6771295724433667
# Image 42: IoU for label 0 = 0.8145665364416639, IoU for label 1 = 0.719293388561754
# Image 43: IoU for label 0 = 0.8084796362902555, IoU for label 1 = 0.743751315251357
# Image 44: IoU for label 0 = 0.8091559693891031, IoU for label 1 = 0.7385219907616881
# Image 45: IoU for label 0 = 0.9127204605033783, IoU for label 1 = 0.43002894163878713
# Image 46: IoU for label 0 = 0.9517788370493918, IoU for label 1 = 0.56202976398521
# Image 47: IoU for label 0 = 0.7146492004394531, IoU for label 1 = 0.0
# Image 48: IoU for label 0 = 0.7188758850097656, IoU for label 1 = 0.0
# Image 49: IoU for label 0 = 0.8541593551635742, IoU for label 1 = 0.0
# Image 50: IoU for label 0 = 0.8341770172119141, IoU for label 1 = 0.0
# Image 51: IoU for label 0 = 0.969111442565918, IoU for label 1 = 0.0
# Image 52: IoU for label 0 = 0.6020383834838867, IoU for label 1 = 0.0
# Image 53: IoU for label 0 = 0.6205987930297852, IoU for label 1 = 0.0
# Image 54: IoU for label 0 = 0.6001977920532227, IoU for label 1 = 0.0
# Image 55: IoU for label 0 = 0.9115381240844727, IoU for label 1 = 0.0
# Image 56: IoU for label 0 = 0.6121034622192383, IoU for label 1 = 0.0
# Image 57: IoU for label 0 = 0.9745969772338867, IoU for label 1 = 0.0
# Image 58: IoU for label 0 = 0.7157783508300781, IoU for label 1 = 0.0
# Image 59: IoU for label 0 = 0.8901805877685547, IoU for label 1 = 0.0
# Image 60: IoU for label 0 = 0.6755380630493164, IoU for label 1 = 0.0
# Image 61: IoU for label 0 = 0.6927824020385742, IoU for label 1 = 0.0
# Image 62: IoU for label 0 = 0.9922513961791992, IoU for label 1 = 0.0
# Image 63: IoU for label 0 = 0.638026237487793, IoU for label 1 = 0.0
# Image 64: IoU for label 0 = 0.8333873748779297, IoU for label 1 = 0.0
# Image 65: IoU for label 0 = 0.8718366622924805, IoU for label 1 = 0.0
# Image 66: IoU for label 0 = 0.8258228302001953, IoU for label 1 = 0.0
# Image 67: IoU for label 0 = 0.9350309371948242, IoU for label 1 = 0.0
# Image 68: IoU for label 0 = 0.6802911758422852, IoU for label 1 = 0.0
# Image 69: IoU for label 0 = 0.6232032775878906, IoU for label 1 = 0.0
# Image 70: IoU for label 0 = 0.9144477844238281, IoU for label 1 = 0.0
# Image 71: IoU for label 0 = 0.7542648315429688, IoU for label 1 = 0.0
# Image 72: IoU for label 0 = 0.6777467727661133, IoU for label 1 = 0.0
# Image 73: IoU for label 0 = 0.7683782577514648, IoU for label 1 = 0.0
# Image 74: IoU for label 0 = 0.6803483963012695, IoU for label 1 = 0.0
# Image 75: IoU for label 0 = 0.5693235397338867, IoU for label 1 = 0.0
# Image 76: IoU for label 0 = 0.9777116775512695, IoU for label 1 = 0.0
# Image 77: IoU for label 0 = 0.7344331741333008, IoU for label 1 = 0.0
# Image 78: IoU for label 0 = 0.7343177795410156, IoU for label 1 = 0.0
# Image 79: IoU for label 0 = 0.8426504135131836, IoU for label 1 = 0.0
# Image 80: IoU for label 0 = 0.9911394119262695, IoU for label 1 = 0.0
# Image 81: IoU for label 0 = 0.5167570114135742, IoU for label 1 = 0.0
# Image 82: IoU for label 0 = 0.9267721176147461, IoU for label 1 = 0.0
# Image 83: IoU for label 0 = 0.9916343688964844, IoU for label 1 = 0.0
# Image 84: IoU for label 0 = 0.5898942947387695, IoU for label 1 = 0.0
# Image 85: IoU for label 0 = 0.8465681076049805, IoU for label 1 = 0.0
# Image 86: IoU for label 0 = 0.6502590179443359, IoU for label 1 = 0.0
# Image 87: IoU for label 0 = 0.6944808959960938, IoU for label 1 = 0.0
# Image 88: IoU for label 0 = 0.6843671798706055, IoU for label 1 = 0.0
# Image 89: IoU for label 0 = 0.6908187866210938, IoU for label 1 = 0.0
# Image 90: IoU for label 0 = 0.6969995498657227, IoU for label 1 = 0.0
# Image 91: IoU for label 0 = 0.7249670028686523, IoU for label 1 = 0.0
# Image 92: IoU for label 0 = 0.6441574096679688, IoU for label 1 = 0.0
# Image 93: IoU for label 0 = 0.9473171234130859, IoU for label 1 = 0.0
# Image 94: IoU for label 0 = 0.7062339782714844, IoU for label 1 = 0.0
# Image 95: IoU for label 0 = 0.6714563369750977, IoU for label 1 = 0.0
# Image 96: IoU for label 0 = 0.6271162033081055, IoU for label 1 = 0.0
# Image 97: IoU for label 0 = 0.8256263732910156, IoU for label 1 = 0.0
# Image 98: IoU for label 0 = 0.6863918304443359, IoU for label 1 = 0.0
# Image 99: IoU for label 0 = 0.9579181671142578, IoU for label 1 = 0.0
# Image 100: IoU for label 0 = 0.6351718902587891, IoU for label 1 = 0.0
# Image 101: IoU for label 0 = 0.6962966918945312, IoU for label 1 = 0.0
# Image 102: IoU for label 0 = 0.7459402084350586, IoU for label 1 = 0.0
# Image 103: IoU for label 0 = 0.9593391418457031, IoU for label 1 = 0.0
# Image 104: IoU for label 0 = 0.6532764434814453, IoU for label 1 = 0.0
# Image 105: IoU for label 0 = 0.7230319976806641, IoU for label 1 = 0.0
# Image 106: IoU for label 0 = 0.7067499160766602, IoU for label 1 = 0.0
# Image 107: IoU for label 0 = 0.6748313903808594, IoU for label 1 = 0.0
# Image 108: IoU for label 0 = 0.7612781524658203, IoU for label 1 = 0.0
# Image 109: IoU for label 0 = 0.7100048065185547, IoU for label 1 = 0.0
# Image 110: IoU for label 0 = 0.931114507654567, IoU for label 1 = 0.719525902640068
# Image 111: IoU for label 0 = 0.7659090970647903, IoU for label 1 = 0.6421334194584881
# Image 112: IoU for label 0 = 0.981914161390078, IoU for label 1 = 0.608431688885115
# Image 113: IoU for label 0 = 0.7631220005757776, IoU for label 1 = 0.6627026532224524
# Image 114: IoU for label 0 = 0.78770346449775, IoU for label 1 = 0.7180111157079628
# Image 115: IoU for label 0 = 0.7677468282006094, IoU for label 1 = 0.641151058737188
# Image 116: IoU for label 0 = 0.765332338739383, IoU for label 1 = 0.7241615443562194
# Image 117: IoU for label 0 = 0.9107332229614258, IoU for label 1 = 0.0
# Image 118: IoU for label 0 = 0.947790931191206, IoU for label 1 = 0.674756866024455
# Image 119: IoU for label 0 = 0.8366638485524263, IoU for label 1 = 0.47339692166646097
# Image 120: IoU for label 0 = 0.7601672480034216, IoU for label 1 = 0.6949954609907795
# Image 121: IoU for label 0 = 0.9936914443969727, IoU for label 1 = 0.0
# Image 122: IoU for label 0 = 0.9399177437766976, IoU for label 1 = 0.7747535537867513
# Image 123: IoU for label 0 = 0.8138046736058027, IoU for label 1 = 0.7707076300313145
# Image 124: IoU for label 0 = 0.9796180725097656, IoU for label 1 = 0.0
# Image 125: IoU for label 0 = 0.8351995300855392, IoU for label 1 = 0.7856324217630767
# Image 126: IoU for label 0 = 0.7952706011117832, IoU for label 1 = 0.7680400596107894
# Image 127: IoU for label 0 = 0.8318777930736159, IoU for label 1 = 0.7599955772243745
# Image 128: IoU for label 0 = 0.7859216557158238, IoU for label 1 = 0.7015869716839166
# Image 129: IoU for label 0 = 0.8559443573667712, IoU for label 1 = 0.7195555160006611
# Image 130: IoU for label 0 = 0.7799225255783133, IoU for label 1 = 0.6169185213831062
# Image 131: IoU for label 0 = 0.8453364696256903, IoU for label 1 = 0.77475280705226
# Image 132: IoU for label 0 = 0.7988126472383686, IoU for label 1 = 0.7039157957636455
# Image 133: IoU for label 0 = 0.8202050320895099, IoU for label 1 = 0.7311104599063114
# Image 134: IoU for label 0 = 0.8280835026994676, IoU for label 1 = 0.7867597448919426
# Image 135: IoU for label 0 = 0.8470099763566115, IoU for label 1 = 0.7418782431430689
# Image 136: IoU for label 0 = 0.8661542952200392, IoU for label 1 = 0.7839916944509236
# Image 137: IoU for label 0 = 0.9810055952660517, IoU for label 1 = 0.4799128493995111
# Image 138: IoU for label 0 = 0.9636402130126953, IoU for label 1 = 0.0
# Image 139: IoU for label 0 = 0.9728814201768937, IoU for label 1 = 0.628795740032769
# Image 140: IoU for label 0 = 0.8644933700561523, IoU for label 1 = 0.0
# Image 141: IoU for label 0 = 0.7005043029785156, IoU for label 1 = 0.0
# Image 142: IoU for label 0 = 0.9926023483276367, IoU for label 1 = 0.0
# Image 143: IoU for label 0 = 0.7826662063598633, IoU for label 1 = 0.0
# Image 144: IoU for label 0 = 0.738001823425293, IoU for label 1 = 0.0
# Image 145: IoU for label 0 = 0.6901760101318359, IoU for label 1 = 0.0
# Image 146: IoU for label 0 = 0.9992618560791016, IoU for label 1 = 0.0
# Image 147: IoU for label 0 = 1.0, IoU for label 1 = 0.0
# Image 148: IoU for label 0 = 0.7381525039672852, IoU for label 1 = 0.0
# Image 149: IoU for label 0 = 0.733555793762207, IoU for label 1 = 0.0
# Image 150: IoU for label 0 = 0.7488899230957031, IoU for label 1 = 0.0
# Image 151: IoU for label 0 = 0.9035425186157227, IoU for label 1 = 0.0
# Image 152: IoU for label 0 = 0.9999799728393555, IoU for label 1 = 0.0
# Image 153: IoU for label 0 = 0.7587718963623047, IoU for label 1 = 0.0
# Image 154: IoU for label 0 = 0.8517980575561523, IoU for label 1 = 0.0
# Image 155: IoU for label 0 = 0.9263505935668945, IoU for label 1 = 0.0
# Image 156: IoU for label 0 = 0.9713201522827148, IoU for label 1 = 0.0
# Image 157: IoU for label 0 = 0.7551916724843963, IoU for label 1 = 0.5990391753632958
# Image 158: IoU for label 0 = 0.8399837055101249, IoU for label 1 = 0.734673293444875
# Image 159: IoU for label 0 = 0.8671255493511679, IoU for label 1 = 0.7016766339171294
# Image 160: IoU for label 0 = 0.7937634828604611, IoU for label 1 = 0.7319878640400502
# Image 161: IoU for label 0 = 0.9080930489192006, IoU for label 1 = 0.6687935980181238
# Image 162: IoU for label 0 = 0.8462680443665529, IoU for label 1 = 0.612859301374199
# Image 163: IoU for label 0 = 0.8434200647804543, IoU for label 1 = 0.7613391893806467
# Image 164: IoU for label 0 = 0.8217530767312038, IoU for label 1 = 0.7481637346874845
# Image 165: IoU for label 0 = 0.8855872882542349, IoU for label 1 = 0.7308610611246369
# Image 166: IoU for label 0 = 0.9630713449331334, IoU for label 1 = 0.6759502113583719
# Image 167: IoU for label 0 = 0.6990838462038459, IoU for label 1 = 0.7250714588226836
# Image 168: IoU for label 0 = 0.9652374269664277, IoU for label 1 = 0.6088589267939553
# Image 169: IoU for label 0 = 0.9273414241913316, IoU for label 1 = 0.6967880065763197
# Image 170: IoU for label 0 = 0.7296993581002119, IoU for label 1 = 0.697432050080308
# Image 171: IoU for label 0 = 0.9807180504865433, IoU for label 1 = 0.6098632424266518
# Image 172: IoU for label 0 = 0.8078858927581913, IoU for label 1 = 0.7260691732903181
# Image 173: IoU for label 0 = 0.8689631240695878, IoU for label 1 = 0.729094492493886
# Image 174: IoU for label 0 = 0.7349884526558892, IoU for label 1 = 0.7255503973879218
# Image 175: IoU for label 0 = 0.8616771169675036, IoU for label 1 = 0.6923447065466207
# Image 176: IoU for label 0 = 0.9646199569046638, IoU for label 1 = 0.6099157780268312
# Image 177: IoU for label 0 = 0.9384591703728934, IoU for label 1 = 0.7016085918601759
# Image 178: IoU for label 0 = 0.990656852722168, IoU for label 1 = 0.0
# Image 179: IoU for label 0 = 0.9960112060657177, IoU for label 1 = 0.2823509194019591
# Image 180: IoU for label 0 = 0.8229408480909111, IoU for label 1 = 0.7171474801166402
# Image 181: IoU for label 0 = 0.9268202106336574, IoU for label 1 = 0.41745765420262065
# 182
# 94
# Average IoU for label 0: 0.824878933934819
# Average IoU for label 1: 0.673806122518555
